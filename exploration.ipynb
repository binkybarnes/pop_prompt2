# %%
import pandas as pd

# Load transaction history
df = pd.read_csv('data/POP_SalesTransactionHistory.csv', low_memory=False)

# Calculate total profit
total_profit = df['Gross_Profit_adj'].sum()
print(f"Total profit: {total_profit:,.2f}")
# Out:
# Total profit: 119,678,956.63
